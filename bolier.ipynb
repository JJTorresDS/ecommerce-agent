# %%
from agent import agent
from agents import Runner
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
#working
#result = await Runner.run(agent, "What tools can you use?")
#print(result.final_output)

# %% [markdown]
# ## Test Google doc integration

# %%
from google_doc_reader import get_doc_text

doc_id = "1FlKHKxwltF_2S9ADmkfT3B0ajapSMrVKYWRUXf13mno"
creds_path = "secrets/google_service_account.json"  # adjust path if needed

# %%
text = get_doc_text(doc_id, creds_path)
print(text)
# Out:
# Frequently Asked Questions
# Shipping & Delivery
# How long does shipping take? Standard shipping takes 3–5 business days; express is 1–2 business days.
#
# Do you ship internationally? No, we only ship within Argentina.
#
# How much does shipping cost? Orders over $50 ship free; otherwise a flat $5.99 fee applies.
#
# Can I track my order? Yes, you'll receive a tracking link by email once your order ships.
# Sizing & Fit
# How do I find the right size for my child? Check our size chart — we recommend measuring height and chest rather than going by age, since kids' proportions vary.
#
# What if the size doesn't fit? Free exchanges within 30 days — just choose a new size at checkout on your return.
# Returns & Exchanges
# What's your return policy? Unworn items with tags can be returned within 30 days for a full refund.
#
# Can I return sale items? Sale items are final sale / eligible for store credit only.
#
# How do I start a return? Use the "Returns" link in your order confirmation email, or enter your order number on our returns portal.
#
# Who pays for return shipping? Returns due to product defects are on us; all other returns are paid by the customer.
# Product & Materials
# Are your fabrics safe for sensitive skin? Yes — our fabrics are OEKO-TEX certified and free of harsh dyes and chemicals.
#
# How should I wash these clothes? Machine wash cold, tumble dry low. Check the care label for specific items (some prints are wash-cold-only).
#
#
# Orders & Payment
# What payment methods do you accept? Visa, Mastercard, Amex, PayPal, Apple Pay, and Shop Pay.
#
# Can I change or cancel my order after placing it? Orders can be changed within 1 hour of placing them — after that, they're already in fulfillment.
#
# Do you offer gift cards? Yes, digital gift cards from $25–$200 are available.
# Account & Support
# Do I need an account to order? No, guest checkout is available, but an account lets you track orders and save favorites.
#
# How do I contact customer service? Chat with us here, email support@jonas-demo.com, or call 1-800-JONAS-DEMO, Mon–Fri 9am–6pm.

# %% [markdown]
# ## Test Embeddings and Search Tools

# %%
from vector_store import search_products
from embeddings.ingest import update_embedding

update_embedding("SKU-005")

# %%
results = search_products("busco un regalo para mi papa", top_k=5)

for r in results:
    print(r["sku"], "-", r["description"])
# Out:
# SKU-005 - Mochila hombre resistente al agua para laptop de 15 pulgadas, color negro
# SKU-010 - Bolso de mano para mujer, cuero sintético, color café, correa ajustable
# SKU-001 - Zapatillas Nike Air Max para correr, hombre, talla 42, color negro
# SKU-007 - Reloj inteligente deportivo con monitor de ritmo cardíaco, resistente al agua
# SKU-003 - Camiseta de algodón para hombre, cuello redondo, talla M, color azul
