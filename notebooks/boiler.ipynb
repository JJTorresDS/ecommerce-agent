# %%
from ecommerce_agent.agent.factory import agent
from agents import Runner

# %%
#working
#result = await Runner.run(agent, "What tools can you use?")
#print(result.final_output)

# %% [markdown]
# ## Test Google doc integration

# %%
from ecommerce_agent.integrations.google_docs import get_doc_text

doc_id = "1FlKHKxwltF_2S9ADmkfT3B0ajapSMrVKYWRUXf13mno"
creds_path = "secrets/google_service_account.json"

# %%
text = get_doc_text(doc_id, creds_path)
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 text = get_doc_text(doc_id, creds_path)
#       2 print(text)
#
# File ~/Desktop/projects/ecommerce-agent/ecommerce_agent/integrations/google_docs.py:84, in get_doc_text(document_id, creds_path)
#      82 def get_doc_text(document_id: str, creds_path: str | None = None) -> str:
#      83     """Fetch a Google Doc and return its text (ATX headings for HEADING_N)."""
# ---> 84     _, text = get_doc(document_id, creds_path)
#      85     return text
#
# File ~/Desktop/projects/ecommerce-agent/ecommerce_agent/integrations/google_docs.py:75, in get_doc(document_id, creds_path)
#      73 def get_doc(document_id: str, creds_path: str | None = None) -> tuple[str, str]:
#      74     """Fetch a Google Doc and return `(title, text)` with markdown headings."""
# ---> 75     credentials = _credentials(creds_path)
#      76     service = build("docs", "v1", credentials=credentials)
#      77     doc = service.documents().get(documentId=document_id).execute()
#
# File ~/Desktop/projects/ecommerce-agent/ecommerce_agent/integrations/google_docs.py:40, in _credentials(creds_path)
#      38 def _credentials(creds_path: str | None = None):
#      39     path = creds_path or settings.google_service_account_file
# ---> 40     return service_account.Credentials.from_service_account_file(
#      41         path, scopes=SCOPES
#      42     )
#
# File ~/Desktop/projects/ecommerce-agent/.venv/lib/python3.12/site-packages/google/oauth2/service_account.py:271, in Credentials.from_service_account_file(cls, filename, **kwargs)
#     259 @classmethod
#     260 def from_service_account_file(cls, filename, **kwargs):
#     261     """Creates a Credentials instance from a service account json file.
#     262
#     263     Args:
#    (...)    269             credentials.
#     270     """
# --> 271     info, signer = _service_account_info.from_filename(
#     272         filename, require=["client_email", "token_uri"]
#     273     )
#     274     return cls._from_signer_and_info(signer, info, **kwargs)
#
# File ~/Desktop/projects/ecommerce-agent/.venv/lib/python3.12/site-packages/google/auth/_service_account_info.py:78, in from_filename(filename, require, use_rsa_signer)
#      64 def from_filename(filename, require=None, use_rsa_signer=True):
#      65     """Reads a Google service account JSON file and returns its parsed info.
#      66
#      67     Args:
#    (...)     76             info and a signer instance.
#      77     """
# ---> 78     with io.open(filename, "r", encoding="utf-8") as json_file:
#      79         data = json.load(json_file)
#      80         return data, from_dict(data, require=require, use_rsa_signer=use_rsa_signer)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'secrets/google_service_account.json'

# %% [markdown]
# ## Test Embeddings and Search Tools

# %%
from ecommerce_agent.retrieval import search_products
from ecommerce_agent.ingest import update_embedding

# update_embedding("SKU-005")

# %%
results = search_products("busco un regalo para mi papa", top_k=5)

for r in results:
    print(r["sku"], "-", r["description"])
# Out:
# B-001 - ATHENS JACKET — Discount, Winter, Boys, 30% off.
# B-003 - ATHENS JACKET — Discount, Winter, Boys, 30% off.
# B-002 - JR DENIM LONDON COAT — Discount, Winter, Boys, 30% off.
# G-001 - KID LOVE VEST — Discount, Winter, Girls, 50% off.
# G-007 - PRINT JACKET — Discount, Winter, Girls, 40% off.

# %%
from ecommerce_agent.retrieval import list_documents, search_documents

print("Catalog:")
for doc in list_documents():
    print(doc)
# Out:
# Catalog:
# {'document_id': '1FlKHKxwltF_2S9ADmkfT3B0ajapSMrVKYWRUXf13mno', 'filename': '1FlKHKxwltF_2S9ADmkfT3B0ajapSMrVKYWRUXf13mno', 'summary': 'Contains FAQ data', 'has_embedding': True}

# %%
results = search_documents("How do I contact customer service?", top_k=5)

for r in results:
    print(f"[{r['filename']}] chunk {r['chunk_index']}")
    print(r["content"][:400])
    print()
# Out:
# [1FlKHKxwltF_2S9ADmkfT3B0ajapSMrVKYWRUXf13mno] chunk 0
# Frequently Asked Questions
# Shipping & Delivery
# How long does shipping take? Standard shipping takes 3–5 business days; express is 1–2 business days.
#
# Do you ship internationally? No, we only ship within Argentina.
#
# How much does shipping cost? Orders over $50 ship free; otherwise a flat $5.99 fee applies.
#
# Can I track my order? Yes, you'll receive a tracking link by email once your order ships.
# Si

# %%
# Same search, but only inside the Google Doc ingested above
results = search_documents(
    "How do I contact customer service?",
    top_k=5,
    document_id=doc_id,
)

for r in results:
    print(f"[{r['document_id']}] chunk {r['chunk_index']}")
    print(r["content"][:500])
    print()
# Out:
# [1FlKHKxwltF_2S9ADmkfT3B0ajapSMrVKYWRUXf13mno] chunk 0
# Frequently Asked Questions
# Shipping & Delivery
# How long does shipping take? Standard shipping takes 3–5 business days; express is 1–2 business days.
#
# Do you ship internationally? No, we only ship within Argentina.
#
# How much does shipping cost? Orders over $50 ship free; otherwise a flat $5.99 fee applies.
#
# Can I track my order? Yes, you'll receive a tracking link by email once your order ships.
# Sizing & Fit
# How do I find the right size for my child? Check our size chart — we recommend measuring
